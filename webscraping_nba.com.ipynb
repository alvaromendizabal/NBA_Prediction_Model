# %%
years = list(range(2018, 2023))

# %%
url_start = "https://www.nba.com/stats/teams/advanced/?sort=W&dir=-1&Season={}&SeasonType=Regular%20Season.html"

# %%
import requests

# for year in years:
#     url = url_start.format(year)
#     data = requests.get(url)
    
#     with open("nba_data/{}.html".format(year), "w+") as f:
#         f.write(data.text)

# %%
from bs4 import BeautifulSoup as bs

# %%
with open("nba_data/2022.html") as f:
    page = f.read()

# %%
soup = BeautifulSoup(page, "html.parser")

# %%
table_2022 = soup.find(id="nba-stat-table")

# %%
# import pandas as pd

# nba_2022 = pd.read_html(str(table_2022))[0]

# %%
requests.get("https://www.nba.com/stats/teams/advanced/?sort=TEAM_NAME&dir=-1")
# Out:
# <Response [200]>

# %%
requests.request

# %%
import pandas as pd 
# url = 'https://www.nba.com/stats/teams/advanced/?sort=TEAM_NAME&dir=-1'
# fs_df = pd.read_html(url)
# fs_df

# %%
nba_2022 = pd.read_html('./nba_data/Teams Advanced _ Stats _ NBA._2022com.html')

# %%
df = pd.DataFrame(nba_2022[0]).dropna(axis=1)

# %%
df
# Out:
#     Unnamed: 0                    TEAM  GP   W   L     MIN  OffRtg  DefRtg  \
# 0            1            Phoenix Suns  82  64  18  3946.0   114.2   106.8
# 1            2       Memphis Grizzlies  82  56  26  3956.0   114.3   108.9
# 2            3   Golden State Warriors  82  53  29  3946.0   112.1   106.6
# 3            3              Miami Heat  82  53  29  3971.0   113.0   108.4
# 4            5        Dallas Mavericks  82  52  30  3951.0   112.5   109.1
# 5            6          Boston Celtics  82  51  31  3981.0   113.6   106.2
# 6            6         Milwaukee Bucks  82  51  31  3951.0   114.3   111.1
# 7            6      Philadelphia 76ers  82  51  31  3961.0   113.0   110.2
# 8            9               Utah Jazz  82  49  33  3946.0   116.2   110.0
# 9           10          Denver Nuggets  82  48  34  3961.0   113.8   111.5
# 10          10         Toronto Raptors  82  48  34  3971.0   112.1   109.9
# ...
